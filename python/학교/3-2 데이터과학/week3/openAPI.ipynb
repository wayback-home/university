# %%
import datetime
import json
import urllib.request
import pandas as pd

ServiceKey = "HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D"

# %%
# [CODE 1]
def get_request_url(url):
    request = urllib.request.Request(url)

    try:
        response = urllib.request.urlopen(request)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode("utf-8")
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

# %%
# [CODE 2]
def get_tourism_stats_item(yyyymm, national_code, ed_cd):
    service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"

    parameters = "?_type=json&serviceKey=" + ServiceKey  # 인증키
    parameters += "&YM=" + yyyymm
    parameters += "&NAT_CD=" + national_code
    parameters += "&ED_CD=" + ed_cd

    url = service_url + parameters
    print(url)  # 액세스 거부 여부 확인용 출력

    
    result_data = get_request_url(url)

    if result_data is None:
        return None
    else:
        return json.loads(result_data)

# %%
# [CODE 3]
def get_tourism_stats_service(nat_cd, ed_cd, start_year, end_year):
    json_result = []
    result = []
    nat_name = ""
    ed = ""
    data_end = ""

    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))
            json_data = get_tourism_stats_item(yyyymm, nat_cd, ed_cd)  # [CODE 2]

            if json_data["response"]["header"]["resultMsg"] == "OK":
                # 데이터가 없는 마지막 항목인 경우 ----------------------------
                if json_data["response"]["body"]["items"] == "":
                    data_end = "{0}{1:0>2}".format(str(year), str(month - 1))
                    print("data_end = ", data_end)
                    print(
                        "데이터 없음.... \n 제공되는 통계 데이터는 %s년 %s월까지 입니다."
                        % (str(year), str(month - 1))
                    )
                    break

                # json_data를 출력하여 확인...........................................
                print(
                    json.dumps(json_data, indent=4, sort_keys=True, ensure_ascii=False)
                )

                nat_name = json_data["response"]["body"]["items"]["item"]["natKorNm"]
                nat_name = nat_name.replace(" ", "")
                num = json_data["response"]["body"]["items"]["item"]["num"]
                ed = json_data["response"]["body"]["items"]["item"]["ed"]

                print("[ %s_%s : %s ]" % (nat_name, yyyymm, num))
                print("-----------------------------------------------------")
                json_result.append(
                    {
                        "nat_name": nat_name,
                        "nat_cd": nat_cd,
                        "yyyymm": yyyymm,
                        "visit_cnt": num,
                    }
                )

                result.append([nat_name, nat_cd, yyyymm, num])

    # TODO UnboundLocalError: local variable 'data_end' referenced before assignment 해결
    return json_result, result, nat_name, ed, data_end

# %%
# [CODE 0]
def main():
    # 요청변수(Request Parameter)
    # get 국가코드
    nat_cd = input("국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ")
    start_year = int(input("데이터를 몇 년부터 수집할까요? : "))
    end_year = int(input("데이터를 몇 년까지 수집할까요? : "))
    # get 출입국구분코드, E = 방한외래관광객, D = 해외 출국
    ed_cd = "E"

    json_result, result, nat_name, ed, data_end = get_tourism_stats_service(
        nat_cd, ed_cd, start_year, end_year
    )

    # 파일저장 1 : json 파일
    with open(
        "./%s_%s_%d_%s.json" % (nat_name, ed, start_year, data_end),
        "w",
        encoding="utf8",
    ) as outfile:
        json_file = json.dumps(
            json_result, indent=4, sort_keys=True, ensure_ascii=False
        )
        outfile.write(json_file)

    # 파일저장 2 : csv 파일
    columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
    result_df = pd.DataFrame(result, columns=columns)
    result_df.to_csv(
        "./%s_%s_%d_%s.csv" % (nat_name, ed, start_year, data_end),
        index=False,
        encoding="utf8",
    )

# %%
if __name__ == "__main__":
    main()
# Out:
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201201&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.417601] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 244370,
#                     "rnum": 1,
#                     "ym": 201201
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201201 : 244370 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201202&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.445401] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 294317,
#                     "rnum": 1,
#                     "ym": 201202
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201202 : 294317 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201203&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.474897] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 360719,
#                     "rnum": 1,
#                     "ym": 201203
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201203 : 360719 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201204&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.509822] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 298656,
#                     "rnum": 1,
#                     "ym": 201204
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201204 : 298656 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201205&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.535051] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 316598,
#                     "rnum": 1,
#                     "ym": 201205
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201205 : 316598 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201206&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.562065] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 302383,
#                     "rnum": 1,
#                     "ym": 201206
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201206 : 302383 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201207&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.590765] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 299477,
#                     "rnum": 1,
#                     "ym": 201207
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201207 : 299477 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201208&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.617755] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 346950,
#                     "rnum": 1,
#                     "ym": 201208
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201208 : 346950 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201209&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.645011] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 308882,
#                     "rnum": 1,
#                     "ym": 201209
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201209 : 308882 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201210&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.669389] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 269732,
#                     "rnum": 1,
#                     "ym": 201210
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201210 : 269732 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201211&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.695167] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 249481,
#                     "rnum": 1,
#                     "ym": 201211
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201211 : 249481 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201212&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.750966] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 227227,
#                     "rnum": 1,
#                     "ym": 201212
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201212 : 227227 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201301&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.776744] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 206474,
#                     "rnum": 1,
#                     "ym": 201301
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201301 : 206474 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201302&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.801862] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 217153,
#                     "rnum": 1,
#                     "ym": 201302
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201302 : 217153 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201303&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.827552] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 288900,
#                     "rnum": 1,
#                     "ym": 201303
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201303 : 288900 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201304&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.851446] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 202529,
#                     "rnum": 1,
#                     "ym": 201304
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201304 : 202529 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201305&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.879523] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 222936,
#                     "rnum": 1,
#                     "ym": 201305
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201305 : 222936 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201306&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.910248] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 201163,
#                     "rnum": 1,
#                     "ym": 201306
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201306 : 201163 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201307&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:18.937232] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 208219,
#                     "rnum": 1,
#                     "ym": 201307
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201307 : 208219 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201308&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:19.086828] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 270582,
#                     "rnum": 1,
#                     "ym": 201308
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201308 : 270582 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201309&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:19.113945] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 246926,
#                     "rnum": 1,
#                     "ym": 201309
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201309 : 246926 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201310&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:19.142691] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 245021,
#                     "rnum": 1,
#                     "ym": 201310
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201310 : 245021 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201311&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:19.168696] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 222797,
#                     "rnum": 1,
#                     "ym": 201311
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201311 : 222797 ]
# -----------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=HPGTaDn%2FOaGT8JrPDJ9LlcJCALn7QpFFU4LPiv5zwIJtnwM06IijGWhSTpi7T4yLu%2BsWjiBR0ioPJ%2BuoKVdv8Q%3D%3D&YM=201312&NAT_CD=130&ED_CD=E
# [2022-10-17 21:53:19.191398] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num":