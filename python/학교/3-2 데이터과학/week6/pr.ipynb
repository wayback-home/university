# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

# %%
result = []

for page in range(1, 39):
    stock_url = "https://finance.naver.com/sise/sise_market_sum.naver?&page=%d" % page


    html = urllib.request.urlopen(stock_url)
    soupStock = BeautifulSoup(html, "html.parser",from_encoding="euc-kr")
    tag_tbody = soupStock.find("tbody")
    for stock in tag_tbody.find_all("tr",onmouseover="mouseOver(this)"):
        # if len(stock) <= 11:
        #     break
        stock_td = stock.find_all("td")
        stock_title = stock_td[1].string
        stock_price = stock_td[2].string
        stock_yesterday = stock_td[3].find("span").string.strip("\n""\t")
        stock_updown = stock_td[4].find("span").string.strip("\n""\t")
        stock_perPrice = stock_td[5].string
        stock_total = stock_td[6].string
        stock_value = stock_td[7].string
        stock_foreign = stock_td[8].string
        stock_trades = stock_td[9].string
        stock_PER = stock_td[10].string
        stock_ROE = stock_td[11].string
        
        result.append(
            [stock_title]
            + [stock_price]
            + [stock_yesterday]
            + [stock_updown]
            + [stock_perPrice]
            + [stock_total]
            + [stock_value]
            + [stock_foreign]
            + [stock_trades]
            + [stock_PER]
            + [stock_ROE]
        )

# %%
stock_td = pd.DataFrame(result, columns=("종목명","현재가","전일비","등략률","액면가","시가총액","상장주식수","외국인비율","거래량","PER","ROE"))

# %%
stock_td
# Out:
#                   종목명      현재가    전일비     등략률    액면가       시가총액      상장주식수  \
# 0                삼성전자   56,200    100  -0.18%    100  3,355,018  5,969,783
# 1            LG에너지솔루션  482,500  4,500  +0.94%    500  1,129,050    234,000
# 2              SK하이닉스   91,200  1,300  +1.45%  5,000    663,938    728,002
# 3            삼성바이오로직스  811,000  1,000  -0.12%  2,500    577,221     71,174
# 4               삼성전자우   51,100    500  +0.99%    100    420,495    822,887
# ...               ...      ...    ...     ...    ...        ...        ...
# 1863     KBSTAR 모멘텀밸류   11,785     85  +0.73%      0         12        100
# 1864  KBSTAR 200에너지화학    9,795     80  +0.82%      0         12        120
# 1865  KBSTAR 200생활소비재    6,175      5  +0.08%      0         11        180
# 1866    KBSTAR 200산업재   10,415     10  -0.10%      0          8         80
# 1867  KBSTAR 200경기소비재    8,915      0   0.00%      0          7         80
#
#       외국인비율         거래량     PER    ROE
# 0     49.44  15,907,472    8.52  13.92
# 1      4.40     256,331  801.50  10.68
# 2     50.24   2,405,984    5.78  16.84
# 3     10.51      36,035  107.86   8.21
# 4     71.48   1,116,192    7.75    N/A
# ...     ...         ...     ...    ...
# 1863   0.00           8     N/A    N/A
# 1864   0.00       4,946     N/A    N/A
# 1865   0.00          20     N/A    N/A
# 1866   0.00          18     N/A    N/A
# 1867   0.00           6     N/A    N/A
#
# [1868 rows x 11 columns]

# %%
stock_td.to_csv("stock_test.csv",encoding="UTF-8",mode="w",index=True)
